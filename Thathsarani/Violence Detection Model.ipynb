# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow 
import keras
from collections import deque
import matplotlib.pyplot as plt
plt.style.use("seaborn")
from keras.models import load_model
# %matplotlib inline
 
from sklearn.model_selection import train_test_split
 
from keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

# %% [markdown]
# **Visualize Data**

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))
 
# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('F:\DSGP\Violence Detection\Dataset')
 
# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)), 2)
 
# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):
 
    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]
 
    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'F:\DSGP\Violence Detection\Dataset/{selected_class_Name}')
 
    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)
 
    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'F:\DSGP\Violence Detection\Dataset/{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()
 
    # Release the VideoCapture object. 
    video_reader.release()
 
    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
 
    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);
    plt.imshow(rgb_frame);
    plt.axis('off')

# %% [markdown]
# # Extracting Frames

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT, IMAGE_WIDTH = 64, 64
 
# Specify the number of frames of a video that will be fed to the model as one sequence.
NUM_FRAMES = 16
 

DATASET_DIR = "F:\DSGP\Violence Detection\Dataset"
 
CLASSES_LIST = ["Non-Violence","Violence"]

OUTPUT_PATH = "F:\DSGP\Violence Detection\Data Frames/"

# %%
def frames_extraction(video_path):
 
    frames_list = []
    
    # Read the Video File
    video_reader = cv2.VideoCapture(video_path)
 
    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
 
    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/NUM_FRAMES), 1)
 
    # Iterate through the Video Frames.
    for frame_counter in range(NUM_FRAMES):
 
        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
 
        # Reading the frame from the video. 
        success, frame = video_reader.read() 
 
        if not success:
            break
 
        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
 
    print('Done ' + str(video_path))
    video_reader.release()
 
    return frames_list

# %% [markdown]
# # Creating the Data

# %%
def create_dataset():
 
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes.
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)
 
            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)
 
            # Check if the extracted frames are equal to the NUM_FRAMES specified.
            # So ignore the vides having frames less than the NUM_FRAMES.
            if len(frames) == NUM_FRAMES:
 
                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)
 
    features = np.asarray(features)
    labels = np.array(labels)  

    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: Non-Violence
# Done F:\DSGP\Violence Detection\Dataset\Non-Violence\nv1.mov
# Done F:\DSGP\Violence Detection\Dataset\Non-Violence\nv10.mp4
# Done F:\DSGP\Violence Detection\Dataset\Non-Violence\n
mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_890.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_891.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_892.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_893.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_894.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_895.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_896.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_897.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_898.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_899.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_9.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_90.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_900.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_901.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_902.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_903.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_904.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_905.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_906.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_907.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_908.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_909.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_91.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_910.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_911.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_912.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_913.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_914.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_915.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_916.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_917.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_918.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_919.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_92.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_920.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_921.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_922.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_923.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_924.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_925.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_926.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_927.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_928.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_929.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_93.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_930.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_931.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_932.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_933.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_934.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_935.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_936.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_937.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_938.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_939.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_94.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_940.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_941.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_942.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_943.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_944.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_945.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_946.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_947.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_948.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_949.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_95.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_950.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_951.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_952.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_953.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_954.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_955.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_956.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_957.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_958.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_959.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_96.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_960.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_961.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_962.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_963.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_964.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_965.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_966.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_967.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_968.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_969.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_97.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_970.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_971.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_972.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_973.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_974.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_975.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_976.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_977.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_978.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_979.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_98.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_980.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_981.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_982.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_983.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_984.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_985.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_986.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_987.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_988.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_989.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_99.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_990.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_991.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_992.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_993.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_994.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_995.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_996.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_997.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_998.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\V_999.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV1.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV10.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV100.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV101.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV102.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV103.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV104.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV105.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV106.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV107.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV108.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV109.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV11.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV110.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV111.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV112.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV113.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV114.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV115.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV116.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV117.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV118.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV119.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV12.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV120.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV121.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV122.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV123.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV124.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV13.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV14.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV15.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV16.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV17.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV18.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV19.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV2.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV20.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV21.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV22.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV23.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV24.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV25.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV26.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV27.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV28.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV29.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV3.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV30.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV31.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV32.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV33.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV34.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV35.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV36.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV37.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV38.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV39.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV4.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV40.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV41.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV42.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV43.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV44.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV45.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV46.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV47.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV48.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV49.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV5.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV50.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV51.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV52.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV53.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV54.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV55.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV56.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV57.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV58.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV59.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV6.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV60.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV61.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV62.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV63.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV64.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV65.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV66.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV67.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV68.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV69.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV7.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV70.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV71.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV72.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV73.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV74.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV75.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV76.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV77.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV78.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV79.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV8.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV80.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV81.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV82.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV83.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV84.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV85.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV86.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV87.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV88.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV89.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV9.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV90.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV91.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV92.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV93.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV94.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV95.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV96.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV97.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV98.mp4
# Done F:\DSGP\Violence Detection\Dataset\Violence\WV99.mp4

# %%
# Saving the extracted data
np.save("features.npy",features)
np.save("labels.npy",labels)
np.save("video_files_paths.npy",video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy") , np.load("labels.npy") ,  np.load("video_files_paths.npy")

# %% [markdown]
# # Encoding and Splitting Training-Testing Sets

# %%
# convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 90% ) and Test Set ( 10% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.1, shuffle = True, random_state = 42)

# %%
print(features_train.shape,labels_train.shape)
print(features_test.shape, labels_test.shape)
# Out:
# (2220, 16, 64, 64, 3) (2220, 2)
# (247, 16, 64, 64, 3) (247, 2)

# %% [markdown]
# # Importing MobileNet and Fine-Tuning it.

# %%
from keras.applications.mobilenet_v2 import MobileNetV2

mobilenet = MobileNetV2( include_top=False , weights="imagenet")

#Fine-Tuning to make the last 40 layer trainable
mobilenet.trainable=True

for layer in mobilenet.layers[:-40]:
    layer.trainable=False

mobilenet.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 1,681,536
# Non-trainable params: 576,448
# __________________________________________________________________________________________________

# %% [markdown]
# # Building The Model

# %%
def create_model():
 
    model = Sequential()
    
    #Specifying Input to match features shape
    model.add(Input(shape = (NUM_FRAMES, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    # Passing mobilenet in the TimeDistributed layer to handle the sequence
    model.add(TimeDistributed(mobilenet))
    
    model.add(Dropout(0.25))
                                    
    model.add(TimeDistributed(Flatten()))

    # BiLSTM layer
    lstm_fw = LSTM(units=32)
    lstm_bw = LSTM(units=32, go_backwards = True)  

    model.add(Bidirectional(lstm_fw, backward_layer = lstm_bw))
    
    model.add(Dropout(0.25))

    # Dense layers
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.25))

    model.add(Dense(32,activation='relu'))
    model.add(Dropout(0.25))
    
    
    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))
 
    model.summary()
    
    return model

# %%
# Constructing the Model
Violence_model = create_model()

# Plot the structure of the contructed LRCN model.
plot_model(Violence_model, to_file = 'Violence_model_structure_plot.png', show_shapes = True, show_layer_names = True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 16, 2, 2, 1280)   2257984
#  ibuted)
#
#  dropout (Dropout)           (None, 16, 2, 2, 1280)    0
#
#  time_distributed_1 (TimeDis  (None, 16, 5120)         0
#  tributed)
#
#  bidirectional (Bidirectiona  (None, 64)               1319168
#  l)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 256)               16640
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 3,637,090
# Trainable params: 3,060,642
# Non-trainable params: 576,448
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Specifying Callbacks and Fitting

# %%
# Create Early Stopping Callback to monitor the accuracy
early_stopping_callback = EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights = True)

# Create ReduceLROnPlateau Callback to reduce overfitting by decreasing learning
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                  factor=0.6,
                                                  patience=5,
                                                  min_lr=0.00005,
                                                  verbose=1)
 
# Compiling the model 
Violence_model.compile(loss = 'categorical_crossentropy', optimizer = 'sgd', metrics = ["accuracy"])
 
# Fitting the model 
Violence_model_history = Violence_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 8 , shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback,reduce_lr])
# Out:
# Epoch 1/50
# 222/222 [==============================] - 705s 3s/step - loss: 0.6983 - accuracy: 0.4966 - val_loss: 0.6920 - val_accuracy: 0.4910 - lr: 0.0100
# Epoch 2/50
# 222/222 [==============================] - 618s 3s/step - loss: 0.6922 - accuracy: 0.5315 - val_loss: 0.6821 - val_accuracy: 0.5788 - lr: 0.0100
# Epoch 3/50
# 222/222 [==============================] - 527s 2s/step - loss: 0.6572 - accuracy: 0.6030 - val_loss: 0.5805 - val_accuracy: 0.7500 - lr: 0.0100
# Epoch 4/50
# 222/222 [==============================] - 598s 3s/step - loss: 0.5716 - accuracy: 0.7202 - val_loss: 0.5002 - val_accuracy: 0.7703 - lr: 0.0100
# Epoch 5/50
# 222/222 [==============================] - 576s 3s/step - loss: 0.4763 - accuracy: 0.8024 - val_loss: 0.4695 - val_accuracy: 0.7748 - lr: 0.0100
# Epoch 6/50
# 222/222 [==============================] - 717s 3s/step - loss: 0.3953 - accuracy: 0.8452 - val_loss: 0.5563 - val_accuracy: 0.7613 - lr: 0.0100
# Epoch 7/50
# 222/222 [==============================] - 748s 3s/step - loss: 0.3308 - accuracy: 0.8739 - val_loss: 0.3982 - val_accuracy: 0.8221 - lr: 0.0100
# Epoch 8/50
# 222/222 [==============================] - 554s 2s/step - loss: 0.2884 - accuracy: 0.8930 - val_loss: 0.3606 - val_accuracy: 0.8694 - lr: 0.0100
# Epoch 9/50
# 222/222 [==============================] - 549s 2s/step - loss: 0.2260 - accuracy: 0.9172 - val_loss: 0.3746 - val_accuracy: 0.8671 - lr: 0.0100
# Epoch 10/50
# 222/222 [==============================] - 528s 2s/step - loss: 0.2361 - accuracy: 0.9167 - val_loss: 0.3036 - val_accuracy: 0.8919 - lr: 0.0100
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0004665599903091788.
# 222/222 [==============================] - 814s 4s/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.4080 - val_accuracy: 0.9302 - lr: 7.7760e-04
# Epoch 46/50
# 222/222 [==============================] - 813s 4s/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.4097 - val_accuracy: 0.9324 - lr: 4.6656e-04
# Epoch 47/50
# 222/222 [==============================] - 863s 4s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.4094 - val_accuracy: 0.9324 - lr: 4.6656e-04
# Epoch 48/50
# 222/222 [==============================] - 875s 4s/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.4040 - val_accuracy: 0.9324 - lr: 4.6656e-04
# Epoch 49/50
# 222/222 [==============================] - 875s 4s/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.4078 - val_accuracy: 0.9324 - lr: 4.6656e-04
# Epoch 50/50
# 222/222 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9994
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.00027993599069304765.
# 222/222 [==============================] - 795s 4s/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.4107 - val_accuracy: 0.9347 - lr: 4.6656e-04

# %%
Violence_model.save('violence-detection.h5', overwrite=True, include_optimizer=True)

# %%
model_evaluation_history = Violence_model.evaluate(features_test, labels_test)
# Out:
# 8/8 [==============================] - 3s 407ms/step - loss: 0.5273 - accuracy: 0.9028

# %% [markdown]
# # Model Evaluation

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Get the Epochs Count
    epochs = range(len(metric_value_1))
 
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'orange', label = metric_name_2)
 
    plt.title(str(plot_name))
 
    plt.legend()

# %%
plot_metric(Violence_model_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(Violence_model_history, 'accuracy', 'val_accuracy', 'Total Loss vs Total Validation Loss')

# %% [markdown]
# # Predicting the Test Set

# %%
labels_predict = Violence_model.predict(features_test)
# Out:
# 8/8 [==============================] - 4s 393ms/step

# %%
# Decoding the data to use in Metrics
labels_predict = np.argmax(labels_predict , axis=1)
labels_test_normal = np.argmax(labels_test , axis=1)

# %%
labels_test_normal.shape , labels_predict.shape
# Out:
# ((247,), (247,))

# %% [markdown]
# Accuracy Score

# %%
from sklearn.metrics import accuracy_score
AccScore = accuracy_score(labels_predict, labels_test_normal)
print('Accuracy Score is : ', AccScore)
# Out:
# Accuracy Score is :  0.902834008097166

# %% [markdown]
# Confusion Matrix

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

ax= plt.subplot()
cm=confusion_matrix(labels_test_normal, labels_predict)
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['True', 'False']); ax.yaxis.set_ticklabels(['NonViolence', 'Violence']);

# %% [markdown]
# Classification Report

# %%
from sklearn.metrics import classification_report

ClassificationReport = classification_report(labels_test_normal,labels_predict)
print('Classification Report is : \n', ClassificationReport)
# Out:
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       124
#            1       0.88      0.93      0.91       123
#
#     accuracy                           0.90       247
#    macro avg       0.90      0.90      0.90       247
# weighted avg       0.90      0.90      0.90       247
